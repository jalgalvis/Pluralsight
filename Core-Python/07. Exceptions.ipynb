# %% [markdown]
# # <font color=slate>Exceptions</font><h1>
# ***
# ## <center><font color=tomato>Exceptions and Control Flow</font><center>

# %%
from exceptional import convert
convert("one three three seven".split())
# Out:
# 1337

# %% [markdown]
# when the function is called with strings different than number names:
#
# `convert("around the world".split())`
#
# we get the following error:

# %% [raw]
# KeyError                                  Traceback (most recent call last)
#
# <ipython-input-2-c26c0fcfa0d8> in <module>
# ----> 1 convert("around the world".split())
#
# ~/PycharmProjects/courses/corePython_gettingStarted/exceptional.py in convert(s)
#      14     number = ''
#      15     for token in s:
# ---> 16         number += DIGIT_MAP[token]
#      17     x = int(number)
#      18     return x
#
# KeyError: 'around'

# %% [markdown]
# the digit map raised a key error

# %% [markdown]
# ### <font color=lightGreen>Exception propagation</font><h3>

# %%
from IPython.core.display import Image, display
display(Image('img/image10.png'))

# %% [markdown]
# ### <font color=lightGreen>Handling exceptions</font></h3>
#
# In the exceptional.py file it has been introduced `try` and `except` blocks
#
# `try` block contains code that might raise an exception, and
#
# `except` block contains code that handle that potential exception
#
#  with print statements for clarity

# %%
from exceptional import convertWithHandlingExceptionKeyError
convertWithHandlingExceptionKeyError("one three".split())
# Out:
# Conversion succeeded x = 13
# 13

# %%
convertWithHandlingExceptionKeyError("eleventeen")
# Out:
# Conversion failed
# -1

# %% [markdown]
# Now we call the function with a different type:
#
# `convertWithHandlingExceptionKeyError(546)`
#
# we get a type error
#
# ```
# TypeError                                 Traceback (most recent call last)
#
# <ipython-input-5-c8391aeab87a> in <module>
# ----> 1 convertWithHandlingExceptionKeyError(546)
#
# ~/PycharmProjects/courses/corePython_gettingStarted/exceptional.py in convertWithHandlingExceptionKeyError(s)
#      22     try:
#      23         number = ''
# ---> 24         for token in s:
#      25             number += DIGIT_MAP[token]
#      26         x = int(number)
#
# TypeError: 'int' object is not iterable
# ```

# %%
from exceptional import convertWithHandlingExceptionKeyTypeErrors
convertWithHandlingExceptionKeyTypeErrors(234)
# Out:
# Conversion failed
# -1

# %% [markdown]
# ### <font color=lightGreen>Accessing Except Objects</font></h3>

# %%
from exceptional import convertAccessingExceptionObjects
convertAccessingExceptionObjects(["onon"])
# Out:
# conversion error: KeyError('onon')
# -1

# %% [markdown]
# ### <font color=lightGreen>Re-raising Exceptions</font></h3>
#
# In case the program continues and following instructions might previous errors we can use`raise` to re=raise the exception and locate later
#
# `raise` without an argument re-raises the current exception

# %% [markdown]
# ***
# The following code:

# %% [raw]
# from exceptional import string_log, convertAccessingExceptionObjectsReRaise
# convertAccessingExceptionObjectsReRaise("death".split())

# %% [markdown]
# Raises the following exception:

# %% [raw]
# ---------------------------------------------------------------------------
#
# KeyError                                  Traceback (most recent call last)
#
# <ipython-input-7-6ab4611274eb> in <module>
#       1 from exceptional import string_log, convertAccessingExceptionObjectsReRaise
# ----> 2 convertAccessingExceptionObjectsReRaise("death".split())
#       3
#
# ~/PycharmProjects/courses/corePython_gettingStarted/exceptional.py in convertAccessingExceptionObjectsReRaise(s)
#      75         number = ''
#      76         for token in s:
# ---> 77             number += DIGIT_MAP[token]
#      78         return int(number)
#      79     except(KeyError, TypeError) as e:
#
# KeyError: 'death'

# %% [markdown]
# ### <font color=lightGreen>Raise ValueError instead ZeroDivisionError</font></h3>
#
# The command `!phyton3` let us run scripts like terminal

# %%
# !python3 roots.py
# Out:
# 3.0
# 1.414213562373095

# %%
# !python3 rootsWithError.py
# Out:
# 3.0
# 1.414213562373095
# Traceback (most recent call last):
#   File "rootsWithError.py", line 27, in <module>
#     main()
#   File "rootsWithError.py", line 23, in main
#     print(sqrt(-1))
#   File "rootsWithError.py", line 15, in sqrt
#     guess = (guess + x / guess) / 2.0
# ZeroDivisionError: float division by zero

# %%
# !python3 rootsHandlingException.py
# Out:
# 3.0
# 1.414213562373095
# Cannot compute square root of a negative nnumber
# Program execution continues normally here

# %%
# !python3 rootsRasingException.py
# Out:
# 3.0
# 1.414213562373095
# Cannot compute square root ofnegative number -1
# Program execution continues normally here

# %% [markdown]
# ***
# ## <center><font color=tomato>Exceptions and Protocols</font></center>
#
# >Sequences should raise `IndexError` for out-of-bounds indexing.
# >
# >Exceptions must be implemented and documented correctly
# >
# >Existing built-in exceptions are often the right ones to use
# >
# >The more your code follows established patterns, the easier it will be for others to use
#
# ### <font color=lightGreen>Common exception types</font></h3>
#
# `IndexError`
# An integer index is out of range

# %% [markdown]
# ***
# The following code:

# %% [raw]
# z = [1, 2, 4]
# z[4]

# %% [markdown]
# Raises the folloing exception:

# %% [raw]
# ---------------------------------------------------------------------------
#
# IndexError                                Traceback (most recent call last)
#
# <ipython-input-30-3b91b7bfc97f> in <module>
#       1 z = [1, 2, 4]
# ----> 2 z[4]
#       3
#
# IndexError: list index out of range

# %% [markdown]
# `ValueError` an object is of the correct type but has an inappropriate value

# %% [markdown]
# ***
# The following code:

# %% [raw]
# int("jim")

# %% [markdown]
# Raises the following exception

# %% [raw]
# ---------------------------------------------------------------------------
#
# ValueError                                Traceback (most recent call last)
#
# <ipython-input-31-ede519415a45> in <module>
# ----> 1 int("jim")
#
# ValueError: invalid literal for int() with base 10: 'jim'

# %% [markdown]
# `KeyError` A lookup in mapping failed

# %% [markdown]
# ***
# The following code:

# %% [raw]
# codes = dict(gb=44, us=1, no=47, fe=33, e=34)
# codes['de']

# %% [markdown]
# Raises the following exception:

# %% [raw]
# ---------------------------------------------------------------------------
#
# KeyError                                  Traceback (most recent call last)
#
# <ipython-input-42-ed2a6f9d31ce> in <module>
#       1 codes = dict(gb=44, us=1, no=47, fe=33, e=34)
# ----> 2 codes['de']
#       3
#
# KeyError: 'de'

# %% [markdown]
# ***
# ## <center><font color=tomato>Handle exceptions and cleanup</font></center>
#
# Sometimes it's needed to raise the error and move on with the program, for this matter we can use:
# `finally` in the following way:
#
# <font size=5>
#
# ```
# try:
#     # try-block
# finally:
#     # executed no matter how
#     # the try-block terminates
# ```
#
# </font>
#
# the finally-block always executes
#
# ***
#
# ## <center><font color=tomato>Platform-specific Code</font></center>
#
# The following code is useful to silent an exception about importing a module
# that does not exist and move on with the correct one due to the platform where it is executed.
#
# The second try will not pass silently and let the user to notice what is happening

# %% [raw]
# try:
#     import mscvrt
#
#     def getkey():
#         """Wait for a keypress and return a single character string"""
#         return msvcrt.getch()
#
# except ImportError:
#
#     import sys
#     import tty
#     import termios
#
#     def getkey():
#         """Wait for a keypress and return a single character string"""
#         fd = sys.stdin.fileno()
#         original_attributes = termios.tcgetattr(fd)
#
#         try:
#             tty.setraw(sys.stdin.fileno())
#             ch = sys.stdin.read(1)
#         finally:
#             termios.tcsetattr(fd,termios.TCSADRAIN, original_attributes)
#         return ch
