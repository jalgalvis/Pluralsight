# %%
import numpy as np
import matplotlib.pyplot as plt
import helper
# %matplotlib inline

# %%
x = np.linspace(-np.pi * 2, np.pi * 2, 721)
y = np.sin(x)
for offset, color in zip(np.arange(8), list('rgbcmykw')):
    plt.plot(x, y + offset, c=color);

# %%
data = np.random.randint(0, 10, 10)

# %%
plt.bar(np.arange(len(data)), data, color='b')
plt.plot(data, c='r');

# %%
for color in np.arange(10):
    plt.plot(x, y + color, 'C{}'.format(color));

# %%
plt.rcParams['axes.prop_cycle']
# Out:
# cycler('color', ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf'])

# %%
type(plt.rcParams['axes.prop_cycle'])
# Out:
# cycler.Cycler

# %%
from cycler import cycler

# %%
my_cycler = cycler(color=['#9038FF', '#5233E8', '#4558FF', '#3375E8', '#38B5FF'])

# %%
plt.rc('axes', prop_cycle=my_cycler)

# %%
for offset in range(10):
    plt.plot(x, y + offset);

# %%
plt.rcParams['axes.prop_cycle']
# Out:
# cycler('color', ['#9038FF', '#5233E8', '#4558FF', '#3375E8', '#38B5FF'])

# %%
plt.plot(x, y, c='C1');

# %%
plt.pie(np.random.randint(1, 10, 5));
