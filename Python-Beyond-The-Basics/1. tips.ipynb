# %% [markdown]
# Test Markdown document
# ======================
#
# <h1><font size=5 color=Aquamarine>Colors</font></h1>
#
# <https://www.w3schools.com/colors/colors_names.asp>

# %% [markdown]
# Text
# ----
#
# Here is a paragraph with bold text. **This is some bold text.** Here is a
# paragraph with bold text. __This is also some bold text.__
#
# Here is another one with italic text. *This is some italic text.* Here is
# another one with italic text. _This is some italic text._
#
# Here is another one with struckout text. ~~This is some struckout text.~~ with ~
#
# [//]: # "Pycharm is not rendering bold nor italic text"

# %% [markdown]
# Links
# -----
#
# <https://www.w3schools.com/colors/colors_names.asp>
#
# Autolink: <http://example.com>
#
# Link: [Example](http://example.com)
#
#
# Reference style [link][1].
#
# [1]: http://example.com  "Example"

# %% [markdown]
# Images
# ------
#
# Image: ![My image](http://www.foo.bar/image.png)
#
# [//]: # "Pycharm is not rendering images this way"
# [//]: # "only works with code"

# %%
from IPython.core.display import Image, display
display(Image(url='http://www.agroanalytics.co/wp-content/uploads/2020/02/woman-cleaning-sweet-potatoes-2889093.jpg', width=400, unconfined=True))

from IPython.core.display import Image, display
display(Image('img/image1.png', width=400, unconfined=True))
# Out:
# <img src="http://www.agroanalytics.co/wp-content/uploads/2020/02/woman-cleaning-sweet-potatoes-2889093.jpg" width="400" class="unconfined"/>

# %% [markdown]
# Headers
# -------
#
# # First level title
# ## Second level title
# ### Third level title
# #### Fourth level title
# ##### Fifth level title
# ###### Sixth level title
#
# ### Title with [link](http://localhost)
#
# ### Title with ![image](http://localhost)
# [//]: # "Pycharm is not rendering images this way"

# %% [markdown]
# Code
# ----
#
# ```
# This
#   is
#     code
#       fence
# ```
#
# Inline `code span in a` paragraph.
#
# This is a code block:
#
#     /**
#      * Sorts the specified array into ascending numerical order.
#      *
#      * <p>Implementation note: The sorting algorithm is a Dual-Pivot Quicksort
#      * by Vladimir Yaroslavskiy, Jon Bentley, and Joshua Bloch. This algorithm
#      * offers O(n log(n)) performance on many data sets that cause other
#      * quicksorts to degrade to quadratic performance, and is typically
#      * faster than traditional (one-pivot) Quicksort implementations.
#      *
#      * @param a the array to be sorted
#      */
#     public static void sort(byte[] a) {
#         DualPivotQuicksort.sort(a);
#     }

# %% [markdown]
# Quotes
# ------
#
# > This is the first level of quoting.
# >
# > > This is nested blockquote.
# >
# > Back to the first level.
#
#
# > A list within a blockquote:
# >
# > *	asterisk 1
# > *	asterisk 2
# > *	asterisk 3
#
#
# > Formatting within a blockquote:
# >
# > ### header
# > Link: [Example](http://example.com)

# %% [markdown]
# Html
# -------
#
# This is inline <span>html</html>.
# And this is an html block.
#
# <table>
#   <tr>
#     <th>Column 1</th>
#     <th>Column 2</th>
#   </tr>
#   <tr>
#     <td>Row 1 Cell 1</td>
#     <td>Row 1 Cell 2</td>
#   </tr>
#   <tr>
#     <td>Row 2 Cell 1</td>
#     <td>Row 2 Cell 2</td>
#   </tr>
# </table>

# %% [markdown]
# Horizontal rules
# ----------------
#
# ---
#
# ___
#
#
# ***

# %% [markdown]
# Lists
# -----
#
# Unordered list:
#
# *	asterisk 1
# *	asterisk 2
# *	asterisk 3
#
#
# Ordered list:
#
# 1.	First
# 2.	Second
# 3.	Third
#
#
# Mixed:
#
# 1. First
# 2. Second:
# 	* Fee
# 	* Fie
# 	* Foe
# 3. Third
#
#
# Tables:
#
# | Header 1 | Header 2 |
# | -------- | -------- |
# | Data 1   | Data 2   |

# %% [markdown]
# # Formulas
#
# $e^{i\pi} + 1 = 0$
#
# $$e^x=\sum_{i=0}^\infty \frac{1}{i!}x^i$$
#
# $$e^x=\sum_{i=0}^\infty \frac{1}{i!}x^i$$
